# %%
import cv2
import pytesseract
from matplotlib import pyplot as plt
import numpy as np
import noise_cancellation as nc

# %%
path='drive.jpg'

#read image
img = cv2.imread(path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#show image
plt.imshow(gray)
plt.title('my picture')
plt.show()

# %%
#noise cancellation
img1=nc.process_image_for_ocr(path)

#extract text from image and store as a string
x=pytesseract.image_to_string(img1)

print(x)
# Out:
# Transport Department Government of Delhi
#
# Licence to Drive Vehicls Throughout India
#
# Licence No . : DL-0420110149646 (P) N
# Name : ANURAG BREJA
#
# DOB: 09/02/1976 BG: 0
# Address:
# HNO-178 A2/B MIG FLATS PASCHIM
#
# VIHAR,DELHI 110063
#
# SIWID : BODH RAJ BREJA
#
#
#
# Authorisation to Drive Date of Issue
# INVCRG 01 I 03/ 2011
#
#
#
# (Holder's Signature)
#
# Issue Date : 01/03/2011
# Validity : 08/02/2026 0"}?
# Inv Carr No : NA Issuing Authority (W2)

# %%
type(x)
# Out:
# str

# %%
y=x.split('\n')
y
# Out:
# ['Transport Department Government of Delhi',
#  '',
#  'Licence to Drive Vehicls Throughout India',
#  '',
#  'Licence No . : DL-0420110149646 (P) N',
#  'Name : ANURAG BREJA',
#  '',
#  'DOB: 09/02/1976 BG: 0',
#  'Address:',
#  'HNO-178 A2/B MIG FLATS PASCHIM',
#  '',
#  'VIHAR,DELHI 110063',
#  '',
#  'SIWID : BODH RAJ BREJA',
#  '',
#  ' ',
#  '',
#  'Authorisation to Drive Date of Issue',
#  'INVCRG 01 I 03/ 2011',
#  '',
#  ' ',
#  '',
#  "(Holder's Signature)",
#  '',
#  'Issue Date : 01/03/2011',
#  'Validity : 08/02/2026 0"}?',
#  'Inv Carr No : NA Issuing Authority (W2)']

# %%
z=[]
for i in y:
    if (i!=''):
        z.append(i)

# %%
z
# Out:
# ['Transport Department Government of Delhi',
#  'Licence to Drive Vehicls Throughout India',
#  'Licence No . : DL-0420110149646 (P) N',
#  'Name : ANURAG BREJA',
#  'DOB: 09/02/1976 BG: 0',
#  'Address:',
#  'HNO-178 A2/B MIG FLATS PASCHIM',
#  'VIHAR,DELHI 110063',
#  'SIWID : BODH RAJ BREJA',
#  ' ',
#  'Authorisation to Drive Date of Issue',
#  'INVCRG 01 I 03/ 2011',
#  ' ',
#  "(Holder's Signature)",
#  'Issue Date : 01/03/2011',
#  'Validity : 08/02/2026 0"}?',
#  'Inv Carr No : NA Issuing Authority (W2)']

# %%
m=[]
for i in range (len(z)):
    if 'Address' in z[i]:
       m.append(i)
    elif 'SIWID' in z[i]:
        m.append(i)
print(m)
# Out:
# [5, 8]

# %%
y=''
for i in range (m[0],m[1],1):
    y=y+z[i]

# %%
y
# Out:
# 'Address:HNO-178 A2/B MIG FLATS PASCHIMVIHAR,DELHI 110063'

# %%
m=[]
for i in range (len(z)):
    if 'License No' in z[i]:
       m.append(z[i])
    elif 'Name' in z[i]:
        m.append(z[i])
    elif 'DOB' in z[i]:
        m.append(z[i])
    elif 'SIWID' in z[i]:
        m.append(z[i])
print(m)
# Out:
# ['Name : ANURAG BREJA', 'DOB: 09/02/1976 BG: 0', 'SIWID : BODH RAJ BREJA']

# %%
m.insert(2,y)

# %%
m
# Out:
# ['Name : ANURAG BREJA',
#  'DOB: 09/02/1976 BG: 0',
#  'Address:HNO-178 A2/B MIG FLATS PASCHIMVIHAR,DELHI 110063',
#  'SIWID : BODH RAJ BREJA']
